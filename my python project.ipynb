# %%
from tkinter import*
from tkinter import messagebox
from tkinter import ttk
from PIL import ImageTk,Image
import tkinter.font as font
import sqlite3

root = Tk()
root.title("Sales Managment System For Used Books")
root.iconbitmap("C:/Users/hi/ICON1.ico")

frame = LabelFrame(root,text="WELCOME",borderwidth=15,padx=100,fg="yellow",bg="grey")
frame.pack()

# creating a database or connecting one
conn=sqlite3.connect("Address.db")
#creating cursor
c = conn.cursor()

c.execute("""create table if not exists addresses(
             name text,
             address text,
             state text,
            pincode integer,
            username text,
            password text,
            primary key(username,password)
            );
          
           """)

book=sqlite3.connect("sales.db")
#creating cursor
a = book.cursor()

'''a.execute("""CREATE TABLE book(
          name text,
          author text,
          price integer,
          seller text,
          contact integer
           )""")'''

myFont = font.Font(family='Helvetica')
def check(username,password):
    a=sqlite3.connect('Address.db')
    b=a.cursor()
    store=b.execute('''select * from addresses where
    username='{}' and password='{}';'''.format(username,password))
    store=list(store)
    print(store,username,password)
    if len(store)==0:
        messagebox.askretrycancel("ERROR"," The User Name Or Password That You Had Entered Is Wrong Please Check It And Try Again")
        return        
    else:
        return True
    username.delete(0,END)
    password=delete(0,END)
    a.close()
def login(u,p):
    if not check(str(u),str(p)):return False
    top=Toplevel(bg="blue")
    top.title("You Can Sell Used Books Here")
    top.iconbitmap("C:/Users/hi/ICON1.ico")
    frame = LabelFrame(top,text="WELCOME",borderwidth=15,padx=100,pady=10,fg="yellow",bg="pink")
    frame.pack()
    myLabel = Label(frame, text="Home",bg="blue").pack(anchor=W)

    def info():
        messagebox.showinfo("INFORMATION ABOUT US","NAME = Shaik Humayun Basha                                CONTACT NUMBER = 142867578237") 
    
    def sell():
        top=Toplevel(bg="grey")
        top.title("You Can Sell Used Books Here")
        top.iconbitmap("C:/Users/hi/ICON1.ico")
        button_quit=Button(top,text="Home",bg="blue",command=lambda:top.destroy())
        button_quit.grid(row=0,column=0)
        label0=Label(top,text="",bg="grey",padx=23)
        label0.grid(row=1,column=1)
        label1=Label(top,text="",bg="grey",padx=23)
        label1.grid(row=2,column=1)
        label2=Label(top,text="",bg="grey",padx=23)
        label2.grid(row=3,column=1)
        label=Label(top,text="SELL USED BOOKS",padx=10,pady=10,font=30,bg="sky blue").grid(row=4,column=1,columnspan=2)
           
        def sellbook():
            
              # creating a database or connecting one
            book=sqlite3.connect("sales.db")
             #creating cursor
            a = book.cursor() 
            name1=name.get()
            author1=author.get()
            price1=price.get()
            seller1=seller.get()
            contact1=contact.get()
            if len(name1)==0 or len(author1)==0 or len(price1)==0 or len(seller1)==0 or len(contact1)==0:
                messagebox.showerror("Form Filling Error","HAVE TO FILL ALL THE DATA")
             # create Submit function for database

    
                #insert into the table
            a.execute("INSERT INTO book VALUES(:name1,:author1,:price1,:seller1,:contact1)",
                      
                      {
                          'name1':name1,
                          'author1':author1,
                          'price1':price1,
                          'seller1':seller1,
                          'contact1':contact1
                          
                      })
          
    
    
                     #commit changes
            book.commit()
                   #close connection
            book.close()

    
            # clear the text boxes
            name.delete(0,END)
            author.delete(0,END)
            price.delete(0,END)
            seller.delete(0,END)
            contact.delete(0,END)
    

         #create text boxes
        name=Entry(top,width=30)
        name.grid(row=6,column=2)
        author=Entry(top,width=30)
        author.grid(row=8,column=2)
        price=Entry(top,width=30)
        price.grid(row=10,column=2)
        seller=Entry(top,width=30)
        seller.grid(row=12,column=2)
        contact=Entry(top,width=30)
        contact.grid(row=14,column=2)

        #creat text box lable
        label_2=Label(top,text="",bg="grey",padx=23)
        label_2.grid(row=5,column=1)
        name_label=Label(top,text="Name Of The Book",bg="yellow",padx=23)
        name_label.grid(row=6,column=1)
        label3=Label(top,text="",bg="grey",padx=23)
        label3.grid(row=7,column=1)
        author_label=Label(top,text="Author Of The Book",bg="yellow",padx=20)
        author_label.grid(row=8,column=1)
        label4=Label(top,text="",bg="grey",padx=23)
        label4.grid(row=9,column=1)
        price_label=Label(top,text="Price Of The Book",bg="yellow",padx=26)
        price_label.grid(row=10,column=1)
        label5=Label(top,text="",bg="grey",padx=23)
        label5.grid(row=11,column=1)
        seller_label=Label(top,text="Seller",bg="yellow",padx=60)
        seller_label.grid(row=12,column=1)
        label6=Label(top,text="",bg="grey",padx=23)
        label6.grid(row=13,column=1)
        contact_label=Label(top,text="Contact Number Of Seller",bg="yellow",padx=7)
        contact_label.grid(row=14,column=1)
        label7=Label(top,text="",bg="grey",padx=23)
        label7.grid(row=15,column=1)
        
           # crteat submit button
        submit_btn=Button(top,text="CLICK TO SELL BOOK",command=sellbook)
        submit_btn.grid(row=16,column=1)
        submit_btn['font'] = myFont  
        label8=Label(top,text="",bg="grey",padx=23)
        label8.grid(row=17,column=1)
        button_quit=Button(top,text="Exit",bg="red",command=lambda:root.destroy())
        button_quit.grid(row=18,column=2)
        button_quit['font'] = myFont 

    
    def buy():
        top=Toplevel(bg="grey")
        top.title("You Can See All Used Books Here")
        top.iconbitmap("C:/Users/hi/ICON1.ico")
        main_frame=Frame(top,padx=100)
        main_frame.pack(fill=BOTH,expand=1)
        
        my_canvas=Canvas(main_frame)
        my_canvas.pack(anchor=NE,fill=BOTH,expand=1)
        
        my_scrollbar=ttk.Scrollbar(main_frame,orient=VERTICAL,command=my_canvas.yview)
        my_scrollbar.pack(anchor="nw",fill=BOTH)
        
        my_canvas.configure(yscrollcommand=my_scrollbar.set)
        my_canvas.bind('<Configure>',lambda e:my_canvas.configure(scrollregion=my_canvas.bbox("all")))
        second_frame=Frame(my_canvas,bg="sky blue",padx=100)
        my_canvas.create_window((0,0),window=second_frame,anchor="nw")
                      
        label1=Label(second_frame,text="",bg="sky blue",padx=23).pack()
        label0=Label(second_frame,text="",bg="sky blue",padx=23).pack()
        button_quit=Button(second_frame,text="Home",bg="blue",command=lambda:top.destroy())
        button_quit.pack(anchor=W)
        label2=Label(second_frame,text="",bg="sky blue",padx=23).pack()
        label3=Label(second_frame,text="",bg="sky blue",padx=23).pack()
        label=Label(second_frame,text="BUY USED BOOKS",borderwidth=5,bg="orange",padx=20,pady=10,font=30).pack()
        label4=Label(second_frame,text="",bg="sky blue",padx=23).pack()
         
        def buyer():
                                # creating a database or connecting one
            book=sqlite3.connect("sales.db")
                                 #creating cursor
            a = book.cursor()
                                  #query the data base
            a.execute("SELECT *,oid FROM book")
            records=a.fetchall()
            print(records)
                              #loop through results
            print_records=''
            
            for record in records:
                print_records+=str(record[5])+str(" ) Name Of The Book = ")+str(record[0])+"\n"+str("Author Of The Book = ")+str(record[1])+"\n"+str("Price Of The Book = ")+str(record[2])+"\n"+str("Seller Of The Book = ")+str(record[3])+"\n"+str("Contact Number Of The Seller = ")+str(record[4])+"\n"+"\n"+"\n"
            query_label=Label(second_frame,text=print_records,bg="yellow",padx=50,pady=80)
            query_label.pack()
           #commit changes
            book.commit()
            #close connection
            book.close()
        
        button_buyer=Button(second_frame,text="Click To See All The Available Books",padx=40,pady=20,command=lambda:buyer()).pack()
        button_quit=Button(second_frame,text="Exit",bg="red",command=lambda:root.destroy())
        button_quit.pack(anchor=E)
        button_quit['font'] = myFont   
         
    def buyer():
        top=Toplevel(bg="grey")
        top.title("Select The Method Of Payment")
        top.iconbitmap("C:/Users/hi/ICON1.ico")
        button_quit=Button(top,text="Home",bg="blue",command=lambda:top.destroy())
        button_quit.pack(anchor=W)
        def online():
            messagebox.showerror ("error","Currenty No online Service Is Availabel")
        
        def ofline():
            top=Toplevel(bg="grey")
            top.title("You Can Buy Books Here")
            top.iconbitmap("C:/Users/hi/ICON1.ico")
            button_quit=Button(top,text="Back",bg="blue",padx=10,pady=10,command=lambda:top.destroy())
            button_quit.pack(anchor=W)
            def givedeladd(bg="grey"):
                top=Toplevel(bg="grey")
                top.title("You Can Buy Books Here")
                top.iconbitmap("C:/Users/hi/ICON1.ico")
                button_quit=Button(top,text="Back",bg="blue",padx=10,pady=10,command=lambda:top.destroy())
                button_quit.pack(anchor=W)
            
                conn=sqlite3.connect("AddToDe.db")
                z = conn.cursor()
                '''z.execute("""CREATE TABLE deladd(
                    name text,
                    address text,
                    pincode integer,
                    city text,
                    contact integer
                    )""")'''

                z.execute("INSERT INTO deladd VALUES(:name,:address,:pincode,:city,:contact)",
                          {
                              'name':name.get(),
                              'address':address.get(),
                              'pincode':pincode.get(),
                              'city':city.get(),
                              'contact':contact.get()
                          })
                    #commit changes
                conn.commit()
                    #close connection
                conn.close()
                 # clear the text boxes
                name.delete(0,END)
                address.delete(0,END)
                pincode.delete(0,END)
                city.delete(0,END)
                contact.delete(0,END)
                buy_box=Entry(top,width=30)
                buy_box.pack()
                myLabel0 = Label(top,text="",bg="grey").pack()
                buy_box_label=Label(top,text="Enter The Serial Number Of Book That You Want To Buy And Press the button Buy",bg="sky blue",padx=30,pady=10)
                buy_box_label.pack()
                buy_box.delete(0,END)
                myLabel01 = Label(top,text="",bg="grey").pack()
            
                def buy():
                    # creating a database or connecting one
                    book=sqlite3.connect("sales.db")
                    #creating cursor
                    a = book.cursor()
                      #query the data base
                    a.execute("DELETE from book WHERE oid="+buy_box.get())
                     #commit changes
                    book.commit()
                    #close connection
                    book.close()
                    messagebox.showinfo("Completed","Done successfully")
                    
                myLabel0 = Label(top,text="",bg="grey").pack()
                buttonbuy=Button(top,text="BUY",command=buy)
                buttonbuy.pack()
                myLabel10 = Label(top,text="",bg="grey").pack()
                button_quit=Button(top,text="Exit",bg="red",padx=10,pady=(5),command=lambda:root.destroy())
                button_quit.pack(anchor=E)
            myLabel110=Label(top,text="Give The Address Where The Book Should Be Deliverd",bg="sky blue",padx=300)
            myLabel110.pack()
            myLabel0 = Label(top,text="",bg="grey").pack()
            myLabel01 = Label(top,text="",bg="grey").pack()
            name_label=Label(top,text="Name")
            name_label.pack()
            name=Entry(top,width=30)
            name.pack()
            myLabel002 = Label(top,text="",bg="grey").pack()
            myLabel003 = Label(top,text="",bg="grey").pack()
            address_label=Label(top,text="Address")
            address_label.pack()
            address=Entry(top,width=30)
            address.pack()
            myLabel04 = Label(top,text="",bg="grey").pack()
            myLabel05 = Label(top,text="",bg="grey").pack()
            pincode_label=Label(top,text="Pin Code")
            pincode_label.pack()
            pincode=Entry(top,width=30)
            pincode.pack()
            myLabel06 = Label(top,text="",bg="grey").pack()
            myLabel07 = Label(top,text="",bg="grey").pack()
            city_label=Label(top,text="City")
            city_label.pack()
            city=Entry(top,width=30)
            city.pack()
            myLabel006 = Label(top,text="",bg="grey").pack()
            myLabel007 = Label(top,text="",bg="grey").pack()
            contact_label=Label(top,text="contact")
            contact_label.pack()
            contact=Entry(top,width=30)
            contact.pack()
            myLabel008 = Label(top,text="",bg="grey").pack()
            submit_btn=Button(top,text="DELIVERY ADDRESS",bg="maroon",command=givedeladd)
            submit_btn.pack()
            myLabel09 = Label(top,text="",bg="grey").pack()
            button_quit=Button(top,text="Exit",bg="red",command=lambda:root.destroy())
            button_quit.pack(anchor=E)
            button_quit['font'] = myFont         
            
        myLabel0 = Label(top,text="",bg="grey").pack()
        label=Label(top,text="Select The Method Of Payment",bg="sky blue",padx=300,pady=30).pack()
        button_quit['font'] = myFont
        myLabel01 = Label(top,text="",bg="grey").pack()
        button1=Button(top,text="1) Pay Online",bg="yellow",padx=30,pady=20,command=online)
        button1.pack()
        myLabel02 = Label(top,text="",bg="grey").pack()
        button2=Button(top,text="2) Pay Ofline",bg="yellow",padx=30,pady=20,command=ofline)
        button2.pack()
        myLabel03 = Label(top,text="",bg="grey").pack()
        button_quit=Button(top,text="Exit",bg="red",command=lambda:root.destroy())
        button_quit.pack(anchor=E)
        button_quit['font'] = myFont   
      
    # creating a label widget

    myLabel1 = Label(frame,text="",bg="pink").pack()
    myLabel = Label(frame, text="Sales Managment System For Used Books",fg="black",bg="yellow",bd=10,font=30,padx=100,pady=30).pack(anchor=W)
    myLabel4 = Label(frame,text="",bg="pink").pack()
    myButton=Button(frame,text="1) Click Here To See All Available Books",fg="red",bg="sky Blue",padx=15,pady=10,command=buy)
    myLabel5 = Label(frame,text="",bg="pink")
    myLabel51 = Label(frame,text="",bg="pink")
    myButton1=Button(frame,text="2) Click Here To Sell Books",fg="red",bg="sky Blue",padx=10,pady=10,command=sell)
    myLabel6 = Label(frame,text="",bg="pink")
    myButton_1=Button(frame,text="3) Click Here To Buy Books",fg="red",bg="sky Blue",padx=10,pady=10,command=buyer)
    myLabel8 = Label(frame,text="",bg="pink")
    button=Button(frame,text="4) Information About Us",fg="red",bg="sky Blue",padx=10,pady=10,command=info)
    myLabel7 = Label(frame,text="",bg="pink")
    button_quit=Button(frame,text="Exit",bg="red",command=lambda:root.destroy())
    
# showing it onto the screen
    myButton.pack(anchor=W)
    myLabel5.pack()
    myButton1.pack(anchor=W)
    myLabel6.pack()
    myButton_1.pack(anchor=W)
    myLabel8.pack()
    button.pack(anchor=W)
    myLabel7.pack()
    button_quit.pack(anchor=E)
    button['font'] = myFont
    myButton['font'] = myFont
    myButton1['font'] = myFont
    myButton_1['font'] = myFont
    button_quit['font'] = myFont 
    
def add_acc():
    top=Toplevel()
    top.title("You Can Buy Used Books Here")
    top.iconbitmap("C:/Users/hi/ICON1.ico")    
    
    def submit():
        # creating a database or connecting one
        conn=sqlite3.connect("Address.db")
        #creating cursor
        c = conn.cursor() 
        # create Submit function for database

    
        #insert into the table
        c.execute("INSERT INTO addresses VALUES(:name,:address,:pincode,:city,:username,:password)",
                      
                      {
                          'name':name.get(),
                          'address':address.get(),
                          'pincode':pincode.get(),
                          'city':city.get(),
                          'username':username.get(),
                          'password':password.get()
                          
                      })
          
    
    
        #commit changes
        conn.commit()
        #close connection
        conn.close()

    
         # clear the text boxes
        name.delete(0,END)
        address.delete(0,END)
        pincode.delete(0,END)
        city.delete(0,END)
        username.delete(0,END)
        password.delete(0,END)
    

         #create text boxes
    name=Entry(top,width=30)
    name.grid(row=0,column=1,padx=20)
    address=Entry(top,width=30)
    address.grid(row=1,column=1,padx=20)
    pincode=Entry(top,width=30)
    pincode.grid(row=2,column=1,padx=20)
    city=Entry(top,width=30)
    city.grid(row=3,column=1,padx=20)
    username=Entry(top,width=30)
    username.grid(row=4,column=1,padx=20)
    password=Entry(top,width=30)
    password.grid(row=5,column=1,padx=20)

        #creat text box lable
    name_label=Label(top,text="Name")
    name_label.grid(row=0,column=0)
    address_label=Label(top,text="Address")
    address_label.grid(row=1,column=0)
    pincode_label=Label(top,text="Pin Code")
    pincode_label.grid(row=2,column=0)
    city_label=Label(top,text="City")
    city_label.grid(row=3,column=0)
    username_label=Label(top,text="User Name")
    username_label.grid(row=4,column=0)
    pincode_label=Label(top,text="Password")
    pincode_label.grid(row=5,column=0)

           # crteat submit button
    submit_btn=Button(top,text="CREAT ACCOUNT",command=submit)
    submit_btn.grid(row=6,column=1)
    submit_btn['font'] = myFont  
    button_quit=Button(top,text="Exit",bg="red",command=lambda:top.destroy())
    button_quit.grid(row=8,column=3)
    button_quit['font'] = myFont   
myLabel0 = Label(frame,text="",bg="grey").pack()

myLabel = Label(frame,text="SALES MANAGEMENT SYSTEM OF USED BOOKS",padx=200,pady=30,bg="blue",fg="white").pack()
    
myLabel02 = Label(frame,text="",bg="grey").pack()

my_img=ImageTk.PhotoImage(Image.open("C:/Users/hi/sec.jpeg"))
my_label=Label(frame,image=my_img)
my_label.pack()

myLabel04 = Label(frame,text="",bg="grey").pack()

label=Label(frame,text="User Name",padx=5,bg="maroon",fg="white").pack()    
e=Entry(frame,borderwidth=10)
e.pack()
myLabel06 = Label(frame,text="",bg="grey").pack()

label1=Label(frame,text="Password",padx=8,bg="maroon",fg="white").pack()    
e1=Entry(frame,borderwidth=10)
e1.pack()
    
myLabel08 = Label(frame,text="",bg="grey").pack()

myButton2=Button(frame,text="login",bg="green",command=lambda:login(e.get(),e1.get()))
myButton2.pack()

myLabel12 = Label(frame,text="",bg="grey").pack()

myButton3=Button(frame,text="Add Account",bg="orange",command=add_acc)
myButton3.pack()
myButton3['font'] = myFont

myLabel14 = Label(frame,text="",bg="grey").pack()

button_quit=Button(frame,text="Exit",bg="red",command=lambda:root.destroy())
button_quit.pack(anchor=E)

myButton2['font'] = myFont
button_quit['font'] = myFont

#commit changes
conn.commit()
#close connection
conn.close()
#commit changes
book.commit()
#close connection
book.close()

root.mainloop()
# Out:
# [('hannu', 'ponnur', '522134', 'ponnur', 'hannu', 'hannu')] hannu hannu
# [('Python', 'Neha Baga', 9999, 'Devi Sri Prasad', 22222222222, 1), ('DBMS', 'venky', 20, 'santhosh', 2211122331, 2), ('sarileru nikevaru', 'mahesh', 5555, 'krishna', 7676879879, 3), ('yogi', 'prabhas', 489, 'krishnamraju', 4565467697, 4), ('', '', '', '', '', 5)]
