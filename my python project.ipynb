# %%
from tkinter import*
from tkinter import messagebox
import tkinter.font as font
import sqlite3

root = Tk()
root.title("Sales Managment System For Used Books")
root.iconbitmap("C:/Users/hi/ICON1.ico")

# creating a database or connecting one
conn=sqlite3.connect("Address.db")
#creating cursor
c = conn.cursor()

c.execute("""create table if not exists addresses(
             name text,
             address text,
             state text,
            pincode integer,
            username text,
            password text,
            primary key(username,password)
            );
          
           """)

book=sqlite3.connect("sales.db")
#creating cursor
a = book.cursor()

'''a.execute("""CREATE TABLE book(
          name text,
          author text,
          price integer,
          seller text,
          contact integer
           )""")'''

myFont = font.Font(family='Helvetica')
def check(username,password):
    a=sqlite3.connect('Address.db')
    b=a.cursor()
    store=b.execute('''select * from addresses where
    username='{}' and password='{}';'''.format(username,password))
    store=list(store)
    print(store,username,password)
    if len(store)==0:
    
        return False
    else:
        return True
    
    a.close()
def login(u,p):
    if not check(str(u),str(p)):return False
    top=Toplevel()
    top.title("You Can Sell Used Books Here")
    top.iconbitmap("C:/Users/hi/ICON1.ico")
    frame = LabelFrame(top,text="WELCOME",borderwidth=15,padx=100,pady=100,fg="yellow",bg="pink")
    frame.pack()
    myLabel = Label(frame, text="Home",bg="blue").pack(anchor=W)

    def info():
        messagebox.showinfo("INFORMATION ABOUT US","NAME = Shaik Humayun Basha  ,  Devi Sri Prasad            CONTACT NUMBER = 8660295827") 
    

    def sell():
        top=Toplevel()
        top.title("You Can Sell Used Books Here")
        top.iconbitmap("C:/Users/hi/ICON1.ico")
        button_quit=Button(top,text="Home",bg="blue",command=lambda:top.destroy())
        button_quit.grid(row=0,column=0)
        label=Label(top,text="SELL USED BOOKS",borderwidth=5,padx=20,pady=20,font=30).grid(row=2,column=1)
           
        def sellbook():
              # creating a database or connecting one
            book=sqlite3.connect("sales.db")
             #creating cursor
            a = book.cursor() 
             # create Submit function for database

    
                #insert into the table
            a.execute("INSERT INTO book VALUES(:name,:author,:price,:seller,:contact)",
                      
                      {
                          'name':name.get(),
                          'author':author.get(),
                          'price':price.get(),
                          'seller':seller.get(),
                          'contact':contact.get()
                          
                      })
          
    
    
                     #commit changes
            book.commit()
                   #close connection
            book.close()

    
            # clear the text boxes
            name.delete(0,END)
            author.delete(0,END)
            price.delete(0,END)
            seller.delete(0,END)
            contact.delete(0,END)
    

         #create text boxes
        name=Entry(top,width=30)
        name.grid(row=4,column=2,padx=20)
        author=Entry(top,width=30)
        author.grid(row=5,column=2,padx=20)
        price=Entry(top,width=30)
        price.grid(row=6,column=2,padx=20)
        seller=Entry(top,width=30)
        seller.grid(row=7,column=2,padx=20)
        contact=Entry(top,width=30)
        contact.grid(row=8,column=2,padx=20)

        #creat text box lable
        name_label=Label(top,text="Name Of The Book")
        name_label.grid(row=4,column=1)
        author_label=Label(top,text="Author Of The Book")
        author_label.grid(row=5,column=1)
        price_label=Label(top,text="Price Of The Book")
        price_label.grid(row=6,column=1)
        seller_label=Label(top,text="Seller")
        seller_label.grid(row=7,column=1)
        contact_label=Label(top,text="Contact Number Of Seller")
        contact_label.grid(row=8,column=1)

           # crteat submit button
        submit_btn=Button(top,text="SELL BOOK",command=sellbook)
        submit_btn.grid(row=9,column=1)
        submit_btn['font'] = myFont  
        button_quit=Button(top,text="Exit",bg="red",command=lambda:root.destroy())
        button_quit.grid(row=10,column=3)
        button_quit['font'] = myFont 

    
    def buy():
        top=Toplevel()
        top.title("You Can Buy Used Books Here")
        top.iconbitmap("C:/Users/hi/ICON1.ico")
        button_quit=Button(top,text="Home",bg="blue",command=lambda:top.destroy())
        button_quit.pack(anchor=W)
        label=Label(top,text="BUY USED BOOKS",borderwidth=5,padx=20,pady=20,font=30).pack()
        # create query function
        def buyer():
            # creating a database or connecting one
            book=sqlite3.connect("sales.db")
             #creating cursor
            a = book.cursor()
    
             #query the data base
            a.execute("SELECT *,oid FROM book")
            records=a.fetchall()
            print(records)
    
              #loop through results
            print_records=''
            for record in records[0]:
                print_records+=str(record)+"\n"
        
            query_label=Label(top,text=print_records)
            query_label.pack()
    
                #commit changes
            book.commit()
             #close connection
            book.close()
        button_buyer=Button(top,text="Click To See All The Available Books",padx=30,pady=20,command=lambda:buyer()).pack()
        button_quit=Button(top,text="Exit",bg="red",command=lambda:root.destroy())
        button_quit.pack(anchor=E)
        button_quit['font'] = myFont   
            
    
# creating a label widget
    myLabel1 = Label(frame,text="",bg="pink").pack()
    myLabel2 = Label(frame,text="",bg="pink").pack()
    myLabel = Label(frame, text="Sales Managment System For Used Books",fg="black",bg="yellow",bd=10,font=30,padx=100,pady=30).pack(anchor=W)
    myLabel3 = Label(frame,text="",bg="pink").pack()
    myLabel4 = Label(frame,text="",bg="pink").pack()
    myButton=Button(frame,text="1) click here to BUY Books",fg="red",bg="sky Blue",padx=15,pady=10,command=buy)
    myLabel5 = Label(frame,text="",bg="pink")
    myButton1=Button(frame,text="2) click here to SELL Books",fg="red",bg="sky Blue",padx=10,pady=10,command=sell)
    myLabel6 = Label(frame,text="",bg="pink")
    button=Button(frame,text="3) Information About Us",fg="red",bg="sky Blue",padx=25,pady=10,command=info)
    myLabel7 = Label(frame,text="",bg="pink")
    button_quit=Button(frame,text="Exit",bg="red",command=lambda:root.destroy())
    
# showing it onto the screen
    myButton.pack(anchor=W)
    myLabel5.pack()
    myButton1.pack(anchor=W)
    myLabel6.pack()
    button.pack(anchor=W)
    myLabel7.pack()
    button_quit.pack(anchor=E)
   
    button['font'] = myFont
    myButton['font'] = myFont
    myButton1['font'] = myFont
    button_quit['font'] = myFont 
    
def add_acc():
    top=Toplevel()
    top.title("You Can Buy Used Books Here")
    top.iconbitmap("C:/Users/hi/ICON1.ico")    
    
    def submit():
        # creating a database or connecting one
        conn=sqlite3.connect("Address.db")
        #creating cursor
        c = conn.cursor() 
        # create Submit function for database

    
        #insert into the table
        c.execute("INSERT INTO addresses VALUES(:name,:address,:pincode,:city,:username,:password)",
                      
                      {
                          'name':name.get(),
                          'address':address.get(),
                          'pincode':pincode.get(),
                          'city':city.get(),
                          'username':username.get(),
                          'password':password.get()
                          
                      })
          
    
    
        #commit changes
        conn.commit()
        #close connection
        conn.close()

    
         # clear the text boxes
        name.delete(0,END)
        address.delete(0,END)
        pincode.delete(0,END)
        city.delete(0,END)
        username.delete(0,END)
        password.delete(0,END)
    

         #create text boxes
    name=Entry(top,width=30)
    name.grid(row=0,column=1,padx=20)
    address=Entry(top,width=30)
    address.grid(row=1,column=1,padx=20)
    pincode=Entry(top,width=30)
    pincode.grid(row=2,column=1,padx=20)
    city=Entry(top,width=30)
    city.grid(row=3,column=1,padx=20)
    username=Entry(top,width=30)
    username.grid(row=4,column=1,padx=20)
    password=Entry(top,width=30)
    password.grid(row=5,column=1,padx=20)

        #creat text box lable
    name_label=Label(top,text="Name")
    name_label.grid(row=0,column=0)
    address_label=Label(top,text="Address")
    address_label.grid(row=1,column=0)
    pincode_label=Label(top,text="Pin Code")
    pincode_label.grid(row=2,column=0)
    city_label=Label(top,text="City")
    city_label.grid(row=3,column=0)
    username_label=Label(top,text="User Name")
    username_label.grid(row=4,column=0)
    pincode_label=Label(top,text="Password")
    pincode_label.grid(row=5,column=0)

           # crteat submit button
    submit_btn=Button(top,text="CREAT ACCOUNT",command=submit)
    submit_btn.grid(row=6,column=1)
    submit_btn['font'] = myFont  
    button_quit=Button(top,text="Exit",bg="red",command=lambda:top.destroy())
    button_quit.grid(row=8,column=3)
    button_quit['font'] = myFont   

myLabel = Label(root,text="SALES MANAGEMENT SYSTEM OF USED BOOKS",padx=200,pady=30).pack()
    
myLabel0 = Label(root,text="").pack()
myLabel01 = Label(root,text="").pack()
myLabel02 = Label(root,text="").pack()
myLabel03 = Label(root,text="").pack()
myLabel04 = Label(root,text="").pack()
myLabel05 = Label(root,text="").pack()

label=Label(root,text="User Name").pack()    
e=Entry(root,borderwidth=10)
e.pack()
myLabel06 = Label(root,text="").pack()
myLabel07 = Label(root,text="").pack()

label1=Label(root,text="Password").pack()    
e1=Entry(root,borderwidth=10)
e1.pack()
    
myLabel08 = Label(root,text="").pack()
myLabel09 = Label(root,text="").pack()
myLabel10 = Label(root,text="").pack()
myLabel11 = Label(root,text="").pack()

myButton2=Button(root,text="login",bg="green",command=lambda:login(e.get(),e1.get()))
myButton2.pack()

myLabel12 = Label(root,text="").pack()
myLabel13 = Label(root,text="").pack()

myButton3=Button(root,text="Add Account",bg="orange",command=add_acc)
myButton3.pack()
myButton3['font'] = myFont

myLabel14 = Label(root,text="").pack()
myLabel15 = Label(root,text="").pack()

button_quit=Button(root,text="Exit",bg="red",command=lambda:root.destroy())
button_quit.pack(anchor=E)

myButton2['font'] = myFont
button_quit['font'] = myFont

#commit changes
conn.commit()
#close connection
conn.close()
#commit changes
book.commit()
#close connection
book.close()


root.mainloop()
# Out:
# [('hannu', 'ponnur', '522134', 'ponnur', 'hannu', 'hannu')] hannu hannu
